# %%
import numpy as np
import gymnasium as gym
import time
import matplotlib.pyplot as plt

env = gym.make('CartPole-v1', render_mode='rgb_array')
state, info = env.reset()
done = False
action_desc = {0: "向左推", 1: "向右推"}
total_reward = 0.0
reward_list = []
gamma = 0.99

while not done:
    # 清除cell的输出
    # clear_output(wait=True)
    plt.imshow(env.render())
    plt.show()
    action = np.random.choice([0, 1])
    next_state, reward, terminated, truncated, info = env.step(action)
    done = terminated or truncated
    print(
        f"采取动作：{action_desc.get(action, '未知动作')}，获得奖励：{reward}，转移到下一个状态：{next_state}")
    reward_list.append(reward)
    time.sleep(0.1)

# 这里要注意回报是如何逆序计算的
for r in reward_list[::-1]:
    total_reward = r + gamma * total_reward

print('回报（收益）：', total_reward)
env.close()
# Out:
# E:\softsLocation\anoconda\envs\reinforce3\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# 采取动作：向右推，获得奖励：1.0，转移到下一个状态：[-0.03639467  0.24006906 -0.00095669 -0.33969298]
# 采取动作：向右推，获得奖励：1.0，转移到下一个状态：[-0.03159329  0.43520463 -0.00775055 -0.63267744]
# 采取动作：向左推，获得奖励：1.0，转移到下一个状态：[-0.02288919  0.24019164 -0.0204041  -0.3424454 ]
# 采取动作：向右推，获得奖励：1.0，转移到下一个状态：[-0.01808536  0.43559784 -0.02725301 -0.6414921 ]
# 采取动作：向右推，获得奖励：1.0，转移到下一个状态：[-0.0093734   0.6310889  -0.04008285 -0.9426312 ]
# 采取动作：向左推，获得奖励：1.0，转移到下一个状态：[ 0.00324838  0.4365293  -0.05893547 -0.6628074 ]
# 采取动作：向右推，获得奖励：1.0，转移到下一个状态：[ 0.01197896  0.6324195  -0.07219162 -0.9734496 ]
# 采取动作：向左推，获得奖励：1.0，转移到下一个状态：[ 0.02462735  0.43833652 -0.09166061 -0.70428926]
# 采取动作：向左推，获得奖励：1.0，转移到下一个状态：[ 0.03339408  0.24459624 -0.1057464  -0.4418093 ]
# 采取动作：向左推，获得奖励：1.0，转移到下一个状态：[ 0.03828601  0.05111719 -0.11458258 -0.1842434 ]
# 采取动作：向右推，获得奖励：1.0，转移到下一个状态：[ 0.03930835  0.24767628 -0.11826745 -0.5107623 ]
# 采取动作：向右推，获得奖励：1.0，转移到下一个状态：[ 0.04426188  0.44424832 -0.1284827  -0.8382502 ]
# 采取动作：向右推，获得奖励：1.0，转移到下一个状态：[ 0.05314684  0.64086866 -0.1452477  -1.1684198 ]
# 采取动作：向左推，获得奖励：1.0，转移到下一个状态：[ 0.06596421  0.4479036  -0.1686161  -0.92457294]
# 采取动作：向右推，获得奖励：1.0，转移到下一个状态：[ 0.07492229  0.6448524  -0.18710756 -1.265145  ]
# 采取动作：向左推，获得奖励：1.0，转移到下一个状态：[ 0.08781934  0.45254806 -0.21241046 -1.0364122 ]
# 回报（收益）： 14.854222890512437
